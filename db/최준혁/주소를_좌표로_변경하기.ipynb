# %%
import pandas as pd
import aiohttp
import asyncio
import logging
from aiohttp import ClientTimeout
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type

# nest_asyncio 사용
import nest_asyncio
nest_asyncio.apply()

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

KAKAO_API_KEY = ''  # KAKAO REST API 키를 여기에 입력하세요
headers = {"Authorization": f"KakaoAK {KAKAO_API_KEY}"}

# 사용자 정의 예외 클래스 (속도 제한 초과 시 발생)
class RateLimitException(Exception):
    pass

# Kakao API 호출 재시도 설정 (최대 10회 시도, 지수 증가 대기 시간)
@retry(
    stop=stop_after_attempt(10),
    wait=wait_exponential(multiplier=1, min=4, max=300),
    retry=retry_if_exception_type(RateLimitException)
)
async def get_lat_lng(session, address, semaphore):
    url = f"https://dapi.kakao.com/v2/local/search/address.json?query={address}"
    async with semaphore:  # 동시에 처리할 수 있는 요청 수를 제한
        try:
            async with session.get(url, headers=headers, timeout=ClientTimeout(total=30)) as response:
                if response.status == 200:  # 성공적으로 응답을 받은 경우
                    result = await response.json()
                    if result['documents']:
                        # 좌표(y: 위도, x: 경도)를 반환
                        return result['documents'][0]['y'], result['documents'][0]['x']
                elif response.status == 429:  # 속도 제한 초과
                    logging.warning(f"속도 제한 초과: {address}. 재시도 중...")
                    raise RateLimitException("속도 제한 초과")
                else:
                    logging.error(f"예상치 못한 상태 코드 {response.status} (주소: {address})")
        except asyncio.TimeoutError:  # 요청 시간 초과
            logging.error(f"요청 시간 초과 (주소: {address})")
        except RateLimitException:
            raise
        except Exception as e:  # 기타 오류 처리
            logging.error(f"에러 발생 (주소: {address}). 에러: {str(e)}")
    # 좌표를 찾지 못한 경우 None 반환
    return None, None

# 파일 처리 함수
async def process_file(file_path, save_interval=5000):
    data = {}  # 저장할 데이터
    count = 0
    total_processed = 0
    
    semaphore = asyncio.Semaphore(5)  # 동시에 실행할 수 있는 최대 요청 수를 5로 제한
    
    async with aiohttp.ClientSession() as session:
        with open(file_path, 'r', encoding='utf-8') as file:
            while True:
                tasks = []
                batch_data = {}
                
                # 저장 간격(save_interval)만큼 데이터를 처리
                for _ in range(save_interval):
                    line = file.readline()
                    if not line:  # 파일 끝에 도달한 경우
                        break
                    
                    # 파일에서 주소 관련 필드를 추출
                    fields = line.split('|')
                    address = f"{fields[2]} {fields[3]} {fields[4]} {fields[10]} "
                    address += f"{fields[12]}-{fields[13]}" if fields[13] != '0' else fields[12]
                    
                    zipcode = fields[16]
                    building_name = fields[-2] if fields[-2] else None
                    
                    key = (address.strip(), zipcode, building_name)
                    if key not in batch_data:
                        batch_data[key] = {'coordinates': set(), 'address': address.strip(), 'zipcode': zipcode, 'building_name': building_name}
                        # 좌표 검색 작업을 추가
                        tasks.append(asyncio.ensure_future(get_lat_lng(session, address.strip(), semaphore)))
                
                if not tasks:  # 더 이상 처리할 작업이 없으면 종료
                    break
                
                logging.info(f"{len(tasks)}개의 주소를 처리 중...")
                # 작업들을 비동기로 실행하고 결과를 수집
                lat_lng_results = await asyncio.gather(*tasks, return_exceptions=True)
                for i, result in enumerate(lat_lng_results):
                    if isinstance(result, tuple) and result[0] is not None and result[1] is not None:
                        key = list(batch_data.keys())[i]
                        batch_data[key]['coordinates'].add(result)
                    elif isinstance(result, Exception):
                        logging.error(f"에러 발생 (주소: {list(batch_data.keys())[i][0]}). 에러: {str(result)}")
                
                # 처리된 데이터를 저장할 데이터에 추가
                data.update(batch_data)
                total_processed += len(batch_data)
                
                # 데이터가 저장 간격만큼 쌓이면 CSV로 저장
                if len(data) >= save_interval:
                    save_to_csv(data, count)
                    count += len(data)
                    data = {}
                    logging.info(f"총 처리된 데이터 수: {total_processed}, 마지막 배치 크기: {len(batch_data)}")
                
                # 각 배치 처리 후 3초 대기
                await asyncio.sleep(3)
    
    if data:  # 남아있는 데이터를 저장
        save_to_csv(data, count)
        count += len(data)
    
    logging.info(f"총 저장된 데이터 수: {count}개.")
    logging.info(f"총 처리된 주소 수: {total_processed}개.")

# 데이터를 CSV 파일로 저장하는 함수
def save_to_csv(data, count):
    rows = []
    for item in data.values():
        for lat, lng in item['coordinates']:
            rows.append({
                'address': item['address'],
                'zipcode': item['zipcode'],
                'building_name': item['building_name'],
                'latitude': lat,
                'longitude': lng
            })
    
    df = pd.DataFrame(rows)
    # 저장 파일 이름 설정
    filename = f'output_with_coordinates_{count // 1000 + 1}.csv'
    df.to_csv(filename, index=False, encoding='utf-8')
    logging.info(f"{len(rows)}개 데이터를 {filename}에 저장했습니다.")

# Jupyter Notebook에서 호출할 때 사용할 메인 함수
async def main():
    file_path = '/Users/sopung/Desktop/workspace/address/rnaddrkor_seoul.txt'
    await process_file(file_path)

# Jupyter Notebook에서 실행할 때 이 줄을 사용합니다.
await main()
# Out:
# 2024-10-02 09:40:07,002 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:40:43,060 - INFO - 4996개 데이터를 output_with_coordinates_1.csv에 저장했습니다.
# 2024-10-02 09:40:43,061 - INFO - Total processed: 5000, Last batch size: 5000
# 2024-10-02 09:40:46,121 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:41:21,754 - INFO - 5000개 데이터를 output_with_coordinates_6.csv에 저장했습니다.
# 2024-10-02 09:41:21,754 - INFO - Total processed: 10000, Last batch size: 5000
# 2024-10-02 09:41:24,818 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:42:00,234 - INFO - 4995개 데이터를 output_with_coordinates_11.csv에 저장했습니다.
# 2024-10-02 09:42:00,235 - INFO - Total processed: 15000, Last batch size: 5000
# 2024-10-02 09:42:03,434 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:42:39,245 - INFO - 4997개 데이터를 output_with_coordinates_16.csv에 저장했습니다.
# 2024-10-02 09:42:39,245 - INFO - Total processed: 20000, Last batch size: 5000
# 2024-10-02 09:42:42,304 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:43:18,015 - INFO - 4996개 데이터를 output_with_coordinates_21.csv에 저장했습니다.
# 2024-10-02 09:43:18,016 - INFO - Total processed: 25000, Last batch size: 5000
# 2024-10-02 09:43:21,076 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:43:56,417 - INFO - 4998개 데이터를 output_with_coordinates_26.csv에 저장했습니다.
# 2024-10-02 09:43:56,418 - INFO - Total processed: 30000, Last batch size: 5000
# 2024-10-02 09:43:59,617 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:44:35,417 - INFO - 4998개 데이터를 output_with_coordinates_31.csv에 저장했습니다.
# 2024-10-02 09:44:35,418 - INFO - Total processed: 35000, Last batch size: 5000
# 2024-10-02 09:44:38,482 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:45:13,816 - INFO - 4992개 데이터를 output_with_coordinates_36.csv에 저장했습니다.
# 2024-10-02 09:45:13,817 - INFO - Total processed: 40000, Last batch size: 5000
# 2024-10-02 09:45:16,877 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:45:55,228 - INFO - 4995개 데이터를 output_with_coordinates_41.csv에 저장했습니다.
# 2024-10-02 09:45:55,229 - INFO - Total processed: 45000, Last batch size: 5000
# 2024-10-02 09:45:58,289 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:46:35,990 - INFO - 4998개 데이터를 output_with_coordinates_46.csv에 저장했습니다.
# 2024-10-02 09:46:35,990 - INFO - Total processed: 50000, Last batch size: 5000
# 2024-10-02 09:46:39,188 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:47:16,054 - INFO - 4994개 데이터를 output_with_coordinates_51.csv에 저장했습니다.
# 2024-10-02 09:47:16,055 - INFO - Total processed: 55000, Last batch size: 5000
# 2024-10-02 09:47:19,114 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:47:56,070 - INFO - 4996개 데이터를 output_with_coordinates_56.csv에 저장했습니다.
# 2024-10-02 09:47:56,071 - INFO - Total processed: 60000, Last batch size: 5000
# 2024-10-02 09:47:59,132 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:48:35,530 - INFO - 4999개 데이터를 output_with_coordinates_61.csv에 저장했습니다.
# 2024-10-02 09:48:35,531 - INFO - Total processed: 65000, Last batch size: 5000
# 2024-10-02 09:48:38,596 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:49:15,682 - INFO - 4996개 데이터를 output_with_coordinates_66.csv에 저장했습니다.
# 2024-10-02 09:49:15,683 - INFO - Total processed: 70000, Last batch size: 5000
# 2024-10-02 09:49:18,884 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:49:55,529 - INFO - 4997개 데이터를 output_with_coordinates_71.csv에 저장했습니다.
# 2024-10-02 09:49:55,529 - INFO - Total processed: 75000, Last batch size: 5000
# 2024-10-02 09:49:58,597 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:50:42,992 - INFO - 4999개 데이터를 output_with_coordinates_76.csv에 저장했습니다.
# 2024-10-02 09:50:42,993 - INFO - Total processed: 80000, Last batch size: 5000
# 2024-10-02 09:50:46,052 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:51:22,892 - INFO - 4998개 데이터를 output_with_coordinates_81.csv에 저장했습니다.
# 2024-10-02 09:51:22,892 - INFO - Total processed: 85000, Last batch size: 5000
# 2024-10-02 09:51:25,958 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:52:03,650 - INFO - 4999개 데이터를 output_with_coordinates_86.csv에 저장했습니다.
# 2024-10-02 09:52:03,650 - INFO - Total processed: 90000, Last batch size: 5000
# 2024-10-02 09:52:06,716 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:52:44,109 - INFO - 4987개 데이터를 output_with_coordinates_91.csv에 저장했습니다.
# 2024-10-02 09:52:44,110 - INFO - Total processed: 95000, Last batch size: 5000
# 2024-10-02 09:52:47,169 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:53:25,021 - INFO - 4999개 데이터를 output_with_coordinates_96.csv에 저장했습니다.
# 2024-10-02 09:53:25,022 - INFO - Total processed: 100000, Last batch size: 5000
# 2024-10-02 09:53:28,084 - INFO - Processing batch of 5000 addresses...
# 2024-10-02 09:53:28,117 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 연세로
- WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 명물길 71. Retrying...
# 2024-10-02 09:53:29,054 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 명물길 74. Retrying...
# 2024-10-02 09:53:29,057 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 명물길 76-5. Retrying...
# 2024-10-02 09:53:29,060 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 2. Retrying...
# 2024-10-02 09:53:29,070 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 8. Retrying...
# 2024-10-02 09:53:29,072 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 4. Retrying...
# 2024-10-02 09:53:29,077 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 10. Retrying...
# 2024-10-02 09:53:29,080 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 9. Retrying...
# 2024-10-02 09:53:29,082 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 10-3. Retrying...
# 2024-10-02 09:53:29,089 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 10-4. Retrying...
# 2024-10-02 09:53:29,091 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 18. Retrying...
# 2024-10-02 09:53:29,123 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 22. Retrying...
# 2024-10-02 09:53:29,127 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 22-6. Retrying...
# 2024-10-02 09:53:29,128 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 22-9. Retrying...
# 2024-10-02 09:53:29,129 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 22-7. Retrying...
# 2024-10-02 09:53:29,129 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 22-10. Retrying...
# 2024-10-02 09:53:29,151 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 30. Retrying...
# 2024-10-02 09:53:29,156 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 28. Retrying...
# 2024-10-02 09:53:29,158 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 26. Retrying...
# 2024-10-02 09:53:29,158 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 24. Retrying...
# 2024-10-02 09:53:29,178 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 33. Retrying...
# 2024-10-02 09:53:29,185 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 2-5. Retrying...
# 2024-10-02 09:53:29,188 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 31. Retrying...
# 2024-10-02 09:53:29,197 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로20길 22-20. Retrying...
# 2024-10-02 09:53:29,200 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 2-1. Retrying...
# 2024-10-02 09:53:29,201 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 4. Retrying...
# 2024-10-02 09:53:29,210 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 4-2. Retrying...
# 2024-10-02 09:53:29,220 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 4-5. Retrying...
# 2024-10-02 09:53:29,223 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 4-6. Retrying...
# 2024-10-02 09:53:29,228 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 6. Retrying...
# 2024-10-02 09:53:29,229 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 8. Retrying...
# 2024-10-02 09:53:29,236 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 10. Retrying...
# 2024-10-02 09:53:29,238 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 12. Retrying...
# 2024-10-02 09:53:29,245 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 14-4. Retrying...
# 2024-10-02 09:53:29,250 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 14-5. Retrying...
# 2024-10-02 09:53:29,252 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 14-8. Retrying...
# 2024-10-02 09:53:29,255 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 16. Retrying...
# 2024-10-02 09:53:29,258 - WARNING - Rate limit exceeded for address: 서울특별시 서대문구 창천동 성산로22길 18. Retrying...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[10], line 131
#     128     await process_file(file_path)
#     130 # Jupyter Notebook에서 실행할 때
# --> 131 await main()
#
# Cell In[10], line 128, in main()
#     126 async def main():
#     127     file_path = '/Users/sopung/Desktop/workspace/address/rnaddrkor_seoul.txt'
# --> 128     await process_file(file_path)
#
# Cell In[10], line 82, in process_file(file_path, save_interval)
#      79     break
#      81 logging.info(f"Processing batch of {len(tasks)} addresses...")
# ---> 82 lat_lng_results = await asyncio.gather(*tasks, return_exceptions=True)
#      83 for i, result in enumerate(lat_lng_results):
#      84     if isinstance(result, tuple) and result[0] is not None and result[1] is not None:
#
# File /opt/anaconda3/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File /opt/anaconda3/lib/python3.11/asyncio/tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# File /opt/anaconda3/lib/python3.11/site-packages/tenacity/_asyncio.py:88, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#      86 @functools.wraps(fn)
#      87 async def async_wrapped(*args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 88     return await fn(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tenacity/_asyncio.py:47, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      45 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#      46 while True:
# ---> 47     do = self.iter(retry_state=retry_state)
#      48     if isinstance(do, DoAttempt):
#      49         try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /opt/anaconda3/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/anaconda3/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/tenacity/_asyncio.py:50, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      48 if isinstance(do, DoAttempt):
#      49     try:
# ---> 50         result = await fn(*args, **kwargs)
#      51     except BaseException:  # noqa: B902
#      52         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# Cell In[10], line 28, in get_lat_lng(session, address, semaphore)
#      21 @retry(
#      22     stop=stop_after_attempt(10),
#      23     wait=wait_exponential(multiplier=1, min=4, max=300),
#      24     retry=retry_if_exception_type(RateLimitException)
#      25 )
#      26 async def get_lat_lng(session, address, semaphore):
#      27     url = f"https://dapi.kakao.com/v2/local/search/address.json?query={address}"
# ---> 28     async with semaphore:
#      29         try:
#      30             async with session.get(url, headers=headers, timeout=ClientTimeout(total=30)) as response:
#
# File /opt/anaconda3/lib/python3.11/asyncio/locks.py:15, in _ContextManagerMixin.__aenter__(self)
#      14 async def __aenter__(self):
# ---> 15     await self.acquire()
#      16     # We have no use for the "as ..."  clause in the with
#      17     # statement for locks.
#      18     return None
#
# File /opt/anaconda3/lib/python3.11/asyncio/locks.py:387, in Semaphore.acquire(self)
#     385 try:
#     386     try:
# --> 387         await fut
#     388     finally:
#     389         self._waiters.remove(fut)
#
# File /opt/anaconda3/lib/python3.11/asyncio/futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File /opt/anaconda3/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File /opt/anaconda3/lib/python3.11/asyncio/futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:

# %%
# 텍스트 파일에서 특정 항목 위의 텍스트 삭제하기
def remove_text_above_line(file_path, target_line_start, output_file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # 특정 라인을 찾고 그 위의 텍스트를 제거
    for i, line in enumerate(lines):
        if line.startswith(target_line_start):
            lines = lines[i:]  # 해당 라인부터 이후 내용만 남김
            break

    # 결과를 새 파일에 저장
    with open(output_file_path, 'w', encoding='utf-8') as f:
        f.writelines(lines)

# 사용 예시
file_path = '/Users/sopung/Desktop/workspace/address/rnaddrkor_seoul.txt'  # 입력 파일 경로
output_file_path = '/Users/sopung/Desktop/workspace/address/modified_rnaddrkor_seoul.txt'  # 수정된 파일 저장 경로
target_line_start = '11410116311200800001000000'  # 특정 항목의 시작 부분

remove_text_above_line(file_path, target_line_start, output_file_path)
